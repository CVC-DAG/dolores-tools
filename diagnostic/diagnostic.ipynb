# %%
import json
from pathlib import Path

wrong_file_path = Path("wrong_files_old.json")

with open(wrong_file_path) as f_in:
    data = json.load(f_in)
print(len(data))

wrong_svg_path = Path("/home/ptorras/DATA/DoloresDB/Transcriptions/WrongSVG")
right_svg_path = Path("/home/ptorras/DATA/DoloresDB/Transcriptions/SVG")
# Out:
# 817

# %%
from lxml import etree

NAMESPACES = {
    "svg": "http://www.w3.org/2000/svg",
    "xlink": "http://www.w3.org/1999/xlink",
    "mei": "http://www.music-encoding.org/ns/mei",
}

id_mappings = {}  # file-> dict[wrong id, right id]

matched = 0
unmatched = 0
different = 0
for right_svg_file in right_svg_path.glob("*.svg"):
    wrong_svg_file = wrong_svg_path / right_svg_file.name
    if not wrong_svg_file.exists():
        unmatched += 1
    matched += 1

    file_mapping = {}
    id_mappings[right_svg_file.name] = file_mapping

    right_svg_data = etree.parse(right_svg_file)
    wrong_svg_data = etree.parse(wrong_svg_file)

    right_svg_root = right_svg_data.getroot()
    wrong_svg_root = wrong_svg_data.getroot()

    for ii, (right_node, wrong_node) in enumerate(zip(right_svg_root.findall(".//*", namespaces=NAMESPACES),
                                                      wrong_svg_root.findall(".//*", namespaces=NAMESPACES))):
        if right_node.tag == wrong_node.tag:
            if "id" in right_node.attrib and "id" in wrong_node.attrib:
                file_mapping[wrong_node.attrib["id"]] = right_node.attrib["id"]
        else:
            print(
                f"Node tags are different on file {right_svg_file.name} position {ii} and line: L({right_node.sourceline}) > {right_node.tag} vs L({right_node.sourceline}) > {wrong_node.tag}")
            different += 1
            del id_mappings[right_svg_file.name]
            break

print(f"Matched: {matched} -- Unmatched {unmatched}")
print(f"There are {different} different SVG files.")
# Out:
# Node tags are different on file XAC_ACAN_SMIAu63_098.10.svg position 85 and line: L(128) > {http://www.w3.org/2000/svg}path vs L(128) > {http://www.w3.org/2000/svg}use
# Node tags are different on file XAC_ACGAX_SEOAu942.08_016.05.svg position 54 and line: L(81) > {http://www.w3.org/2000/svg}g vs L(81) > {http://www.w3.org/2000/svg}path
# Node tags are different on file XAC_ACAN_SMIAu83_011.09.svg position 18 and line: L(29) > {http://www.w3.org/2000/svg}style vs L(29) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACGAX_SEOAu942.06_003.06.svg position 28 and line: L(43) > {http://www.w3.org/2000/svg}symbol vs L(43) > {http://www.w3.org/2000/svg}style
# Node tags are different on file XAC_ACAN_SMIAu83_086.01.svg position 304 and line: L(454) > {http://www.w3.org/2000/svg}g vs L(454) > {http://www.w3.org/2000/svg}use
# Node tags are different on file XAC_ACAN_SMIAu37_007.05.svg position 597 and line: L(930) > {http://www.w3.org/2000/svg}path vs L(930) > {http://www.w3.org/2000/svg}use
# Node tags are different on file XAC_ACAN_SMIAu83_011.07.svg position 28 and line: L(44) > {http://www.w3.org/2000/svg}style vs L(44) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACAN_SMIAu83_010.06.svg position 230 and line: L(343) > {http://www.w3.org/2000/svg}g vs L(343) > {http://www.w3.org/2000/svg}path
# Node tags are different on file XAC_ACUR_TagFAu128_061.06.svg position 24 and line: L(38) > {http://www.w3.org/2000/svg}style vs L(38) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACAN_SMIAu83_104.10.svg position 18 and line: L(29) > {http://www.w3.org/2000/svg}style vs L(29) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACUR_TagFAu128_053.04.svg position 20 and line: L(32) > {http://www.w3.org/2000/svg}style vs L(32) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACAN_SMIAu63_070.04.svg position 28 and line: L(44) > {http://www.w3.org/2000/svg}style vs L(44) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACGAX_SEOAu942.06_003.04.svg position 177 and line: L(262) > {http://www.w3.org/2000/svg}g vs L(262) > {http://www.w3.org/2000/svg}polygon
# Node tags are different on file XAC_ACAN_SMIAu09_153.02.svg position 22 and line: L(35) > {http://www.w3.org/2000/svg}style vs L(35) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACGAX_SEOAu942.06_003.02.svg position 18 and line: L(29) > {http://www.w3.org/2000/svg}style vs L(29) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACAN_SMIAu85_003.03.svg position 16 and line: L(26) > {http://www.w3.org/2000/svg}style vs L(26) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACUR_TagFAu128_060.03.svg position 12 and line: L(20) > {http://www.w3.org/2000/svg}style vs L(20) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACAN_SMIAu63_063.05.svg position 22 and line: L(35) > {http://www.w3.org/2000/svg}style vs L(35) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACAN_SMIAu83_008.01.svg position 18 and line: L(28) > {http://www.w3.org/2000/svg}symbol vs L(28) > {http://www.w3.org/2000/svg}style
# Node tags are different on file UAB_LICEU_188255.017.04.svg position 104 and line: L(157) > {http://www.w3.org/2000/svg}text vs L(157) > {http://www.w3.org/2000/svg}g
# Node tags are different on file XAC_ACUR_TagFAu128_061.01.svg position 30 and line: L(47) > {http://www.w3.org/2000/svg}style vs L(47) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACAN_SMIAu83_018.03.svg position 177 and line: L(263) > {http://www.w3.org/2000/svg}g vs L(263) > {http://www.w3.org/2000/svg}path
# Node tags are different on file XAC_ACUR_TagFAu128_003.01.svg position 344 and line: L(503) > {http://www.w3.org/2000/svg}path vs L(503) > {http://www.w3.org/2000/svg}use
# Node tags are different on file XAC_ACGAX_SEOAu942.06_003.01.svg position 33 and line: L(46) > {http://www.w3.org/2000/svg}use vs L(46) > {http://www.w3.org/2000/svg}g
# Node tags are different on file XAC_ACAN_SMIAu09_166.04.svg position 18 and line: L(29) > {http://www.w3.org/2000/svg}style vs L(29) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACUR_TechAu14.01_003.02.svg position 946 and line: L(1460) > {http://www.w3.org/2000/svg}path vs L(1460) > {http://www.w3.org/2000/svg}use
# Node tags are different on file XAC_ACAN_SMIAu63_075.04.svg position 26 and line: L(41) > {http://www.w3.org/2000/svg}style vs L(41) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACAN_SMIAu09_127.02.svg position 18 and line: L(29) > {http://www.w3.org/2000/svg}style vs L(29) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACAN_SMIAu83_029.07.svg position 22 and line: L(35) > {http://www.w3.org/2000/svg}style vs L(35) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACAN_SMIAu83_018.15.svg position 175 and line: L(258) > {http://www.w3.org/2000/svg}g vs L(258) > {http://www.w3.org/2000/svg}path
# Node tags are different on file XAC_ACAN_SMIAu09_178.05.svg position 425 and line: L(654) > {http://www.w3.org/2000/svg}path vs L(654) > {http://www.w3.org/2000/svg}use
# Node tags are different on file XAC_ACUR_TagFAu128_052.03.svg position 12 and line: L(20) > {http://www.w3.org/2000/svg}style vs L(20) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file CEDOC_CMM_1.5.1_0186.016.01.svg position 1659 and line: L(2387) > {http://www.w3.org/2000/svg}use vs L(2387) > {http://www.w3.org/2000/svg}g
# Node tags are different on file XAC_ACGAX_SEOAu942.08_008.08.svg position 74 and line: L(106) > {http://www.w3.org/2000/svg}path vs L(106) > {http://www.w3.org/2000/svg}ellipse
# Node tags are different on file XAC_ACAN_SMIAu83_018.08.svg position 171 and line: L(254) > {http://www.w3.org/2000/svg}path vs L(254) > {http://www.w3.org/2000/svg}use
# Node tags are different on file XAC_ACAN_SMIAu63_079.05.svg position 20 and line: L(32) > {http://www.w3.org/2000/svg}style vs L(32) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACAN_SMIAu94_002.03.svg position 30 and line: L(47) > {http://www.w3.org/2000/svg}style vs L(47) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACAN_SMIAu83_018.11.svg position 12 and line: L(19) > {http://www.w3.org/2000/svg}symbol vs L(19) > {http://www.w3.org/2000/svg}style
# Node tags are different on file XAC_ACUR_TagFAu198_002.03.svg position 18 and line: L(29) > {http://www.w3.org/2000/svg}style vs L(29) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACUR_TagFAu198_003.02.svg position 20 and line: L(32) > {http://www.w3.org/2000/svg}style vs L(32) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACAN_SMIAu83_015.14.svg position 76 and line: L(113) > {http://www.w3.org/2000/svg}path vs L(113) > {http://www.w3.org/2000/svg}use
# Node tags are different on file XAC_ACAN_SMIAu83_013.14.svg position 30 and line: L(47) > {http://www.w3.org/2000/svg}style vs L(47) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACAN_SMIAu63_082.04.svg position 20 and line: L(32) > {http://www.w3.org/2000/svg}style vs L(32) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACAN_SMIAu63_088.06.svg position 22 and line: L(35) > {http://www.w3.org/2000/svg}style vs L(35) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACAN_SMIAu83_018.12.svg position 63 and line: L(91) > {http://www.w3.org/2000/svg}g vs L(91) > {http://www.w3.org/2000/svg}use
# Node tags are different on file XAC_ACUR_TagFAu199_001.03.svg position 20 and line: L(32) > {http://www.w3.org/2000/svg}style vs L(32) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACAN_SMIAu83_013.05.svg position 32 and line: L(50) > {http://www.w3.org/2000/svg}style vs L(50) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACAN_SMIAu09_141.11.svg position 16 and line: L(26) > {http://www.w3.org/2000/svg}style vs L(26) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACAN_SMIAu83_103.09.svg position 86 and line: L(130) > {http://www.w3.org/2000/svg}path vs L(130) > {http://www.w3.org/2000/svg}use
# Node tags are different on file XAC_ACAN_SMIAu09_177.01.svg position 18 and line: L(29) > {http://www.w3.org/2000/svg}style vs L(29) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACAN_SMIAu63_093.01.svg position 20 and line: L(32) > {http://www.w3.org/2000/svg}style vs L(32) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACAN_SMIAu83_103.03.svg position 14 and line: L(23) > {http://www.w3.org/2000/svg}style vs L(23) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACGAX_SEOAu942.03_006.06.svg position 18 and line: L(29) > {http://www.w3.org/2000/svg}style vs L(29) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACAN_SMIAu94_002.06.svg position 16 and line: L(26) > {http://www.w3.org/2000/svg}style vs L(26) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACAN_SMIAu94_009.06.svg position 22 and line: L(35) > {http://www.w3.org/2000/svg}style vs L(35) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file UAB_LICEU_185546.033.04.svg position 20 and line: L(32) > {http://www.w3.org/2000/svg}style vs L(32) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACAN_SMIAu09_139.02.svg position 20 and line: L(32) > {http://www.w3.org/2000/svg}style vs L(32) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACAN_SMIAu63_073.06.svg position 171 and line: L(261) > {http://www.w3.org/2000/svg}path vs L(261) > {http://www.w3.org/2000/svg}use
# Node tags are different on file XAC_ACAN_SMIAu83_011.03.svg position 344 and line: L(526) > {http://www.w3.org/2000/svg}path vs L(526) > {http://www.w3.org/2000/svg}use
# Node tags are different on file XAC_ACAN_SMIAu83_018.14.svg position 575 and line: L(854) > {http://www.w3.org/2000/svg}use vs L(854) > {http://www.w3.org/2000/svg}g
# Node tags are different on file XAC_ACAN_SMIAu63_082.01.svg position 24 and line: L(38) > {http://www.w3.org/2000/svg}style vs L(38) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACUR_TagFAu128_053.02.svg position 24 and line: L(38) > {http://www.w3.org/2000/svg}style vs L(38) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACAN_SMIAu63_103.01.svg position 22 and line: L(35) > {http://www.w3.org/2000/svg}style vs L(35) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACAN_SMIAu09_165.02.svg position 26 and line: L(41) > {http://www.w3.org/2000/svg}style vs L(41) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACAN_SMIAu83_086.06.svg position 382 and line: L(569) > {http://www.w3.org/2000/svg}g vs L(569) > {http://www.w3.org/2000/svg}path
# Node tags are different on file XAC_ACGAX_SEOAu942.06_003.03.svg position 201 and line: L(304) > {http://www.w3.org/2000/svg}use vs L(304) > {http://www.w3.org/2000/svg}g
# Node tags are different on file XAC_ACGAX_SEOAu942.06_006.03.svg position 433 and line: L(654) > {http://www.w3.org/2000/svg}g vs L(654) > {http://www.w3.org/2000/svg}path
# Node tags are different on file XAC_ACGAX_SEOAu942.08_016.03.svg position 330 and line: L(500) > {http://www.w3.org/2000/svg}use vs L(500) > {http://www.w3.org/2000/svg}g
# Node tags are different on file XAC_ACAN_SMIAu83_011.12.svg position 28 and line: L(44) > {http://www.w3.org/2000/svg}style vs L(44) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACAN_SMIAu63_085.04.svg position 24 and line: L(38) > {http://www.w3.org/2000/svg}style vs L(38) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACUR_TagFAu128_062.04.svg position 12 and line: L(20) > {http://www.w3.org/2000/svg}style vs L(20) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACUR_TechAu14.01_006.01.svg position 28 and line: L(44) > {http://www.w3.org/2000/svg}style vs L(44) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACGAX_SEOAu942.04_005.06.svg position 18 and line: L(29) > {http://www.w3.org/2000/svg}style vs L(29) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACAN_SMIAu37_002.07.svg position 26 and line: L(41) > {http://www.w3.org/2000/svg}style vs L(41) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file UAB_LICEU_185546.012.09.svg position 20 and line: L(32) > {http://www.w3.org/2000/svg}style vs L(32) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file UAB_LICEU_185546.016.09.svg position 18 and line: L(29) > {http://www.w3.org/2000/svg}style vs L(29) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACAN_SMIAu85_004.04.svg position 28 and line: L(44) > {http://www.w3.org/2000/svg}style vs L(44) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACUR_TagFAu200_004.03.svg position 24 and line: L(38) > {http://www.w3.org/2000/svg}style vs L(38) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACAN_SMIAu63_075.03.svg position 24 and line: L(38) > {http://www.w3.org/2000/svg}style vs L(38) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACUR_TagFAu198_001.04.svg position 24 and line: L(38) > {http://www.w3.org/2000/svg}style vs L(38) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACAN_SMIAu63_098.06.svg position 18 and line: L(29) > {http://www.w3.org/2000/svg}style vs L(29) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACAN_SMIAu63_070.07.svg position 16 and line: L(26) > {http://www.w3.org/2000/svg}style vs L(26) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACAN_SMIAu63_078.08.svg position 18 and line: L(29) > {http://www.w3.org/2000/svg}style vs L(29) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACAN_SMIAu83_010.04.svg position 12 and line: L(20) > {http://www.w3.org/2000/svg}style vs L(20) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACUR_TechAu14.01_004.02.svg position 269 and line: L(409) > {http://www.w3.org/2000/svg}path vs L(409) > {http://www.w3.org/2000/svg}use
# Node tags are different on file XAC_ACUR_TagFAu128_056.04.svg position 12 and line: L(20) > {http://www.w3.org/2000/svg}style vs L(20) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file CEDOC_CMM_1.5.1_0186.029.01.svg position 44 and line: L(68) > {http://www.w3.org/2000/svg}style vs L(68) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACAN_SMIAu83_018.02.svg position 445 and line: L(656) > {http://www.w3.org/2000/svg}use vs L(656) > {http://www.w3.org/2000/svg}g
# Node tags are different on file XAC_ACAN_SMIAu63_019.03.svg position 14 and line: L(23) > {http://www.w3.org/2000/svg}style vs L(23) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACAN_SMIAu94_009.05.svg position 28 and line: L(44) > {http://www.w3.org/2000/svg}style vs L(44) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACAN_SMIAu09_154.02.svg position 370 and line: L(569) > {http://www.w3.org/2000/svg}path vs L(569) > {http://www.w3.org/2000/svg}use
# Node tags are different on file XAC_ACGAX_SEOAu942.06_003.07.svg position 14 and line: L(23) > {http://www.w3.org/2000/svg}style vs L(23) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACUR_TagFAu128_061.02.svg position 16 and line: L(26) > {http://www.w3.org/2000/svg}style vs L(26) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACAN_SMIAu37_002.03.svg position 607 and line: L(941) > {http://www.w3.org/2000/svg}path vs L(941) > {http://www.w3.org/2000/svg}use
# Node tags are different on file XAC_ACAN_SMIAu63_093.09.svg position 16 and line: L(26) > {http://www.w3.org/2000/svg}style vs L(26) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACUR_TagFAu199_002.01.svg position 34 and line: L(53) > {http://www.w3.org/2000/svg}style vs L(53) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file UAB_LICEU_185546.008.04.svg position 20 and line: L(32) > {http://www.w3.org/2000/svg}style vs L(32) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACAN_SMIAu83_002.01.svg position 1729 and line: L(2523) > {http://www.w3.org/2000/svg}g vs L(2523) > {http://www.w3.org/2000/svg}use
# Node tags are different on file XAC_ACUR_TagFAu199_002.05.svg position 28 and line: L(44) > {http://www.w3.org/2000/svg}style vs L(44) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACAN_SMIAu83_010.10.svg position 16 and line: L(26) > {http://www.w3.org/2000/svg}style vs L(26) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACAN_SMIAu63_088.05.svg position 18 and line: L(29) > {http://www.w3.org/2000/svg}style vs L(29) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACGAX_SEOAu942.06_003.08.svg position 266 and line: L(397) > {http://www.w3.org/2000/svg}g vs L(397) > {http://www.w3.org/2000/svg}use
# Node tags are different on file XAC_ACAN_SMIAu63_077.08.svg position 72 and line: L(110) > {http://www.w3.org/2000/svg}path vs L(110) > {http://www.w3.org/2000/svg}use
# Node tags are different on file XAC_ACAN_SMIAu85_006.03.svg position 749 and line: L(1163) > {http://www.w3.org/2000/svg}path vs L(1163) > {http://www.w3.org/2000/svg}use
# Node tags are different on file XAC_ACAN_SMIAu63_091.09.svg position 16 and line: L(26) > {http://www.w3.org/2000/svg}style vs L(26) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file UAB_LICEU_222570.002.01.svg position 30 and line: L(47) > {http://www.w3.org/2000/svg}style vs L(47) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACAN_SMIAu83_010.07.svg position 24 and line: L(38) > {http://www.w3.org/2000/svg}style vs L(38) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACGAX_SEOAu942.06_003.09.svg position 76 and line: L(113) > {http://www.w3.org/2000/svg}path vs L(113) > {http://www.w3.org/2000/svg}g
# Node tags are different on file XAC_ACAN_SMIAu63_063.04.svg position 18 and line: L(29) > {http://www.w3.org/2000/svg}style vs L(29) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACGAX_SEOAu942.06_003.10.svg position 267 and line: L(404) > {http://www.w3.org/2000/svg}path vs L(404) > {http://www.w3.org/2000/svg}use
# Node tags are different on file XAC_ACAN_SMIAu09_140.06.svg position 16 and line: L(26) > {http://www.w3.org/2000/svg}style vs L(26) > {http://www.w3.org/2000/svg}symbol
# Node tags are different on file XAC_ACUR_TagFAu128_006.01.svg position 982 and line: L(1426) > {http://www.w3.org/2000/svg}path vs L(1426) > {http://www.w3.org/2000/svg}use
# Matched: 11186 -- Unmatched 0
# There are 112 different SVG files.

# %%
with open("./mapping.json", "w") as f_out:
    json.dump(id_mappings, f_out, indent=4)

# %%
id_mappings["XAC_ACGAX_SEOAu455.01_004.09.svg"]

# %%
import re

re_line = re.compile(r"(.+)\.(\d{2})\.svg")
line_mappings = {}

for k, v in id_mappings.items():
    match = re_line.match(k)

    if match is None:
        raise ValueError("Malformed filename")

    project_name = f"{match.group(1)}_final.json"
    line_index = int(match.group(2))

    line_mappings.setdefault(project_name, {})

    for wrong_id, right_id in v.items():
        if wrong_id != right_id:
            line_mappings[project_name][f"line{line_index}:{wrong_id}"] = f"line{line_index}:{right_id}"

# %%
with open("./project_mapping.json", "w") as f_out:
    json.dump(line_mappings, f_out, indent=4)

# %%
wrong_annotation_path = Path("/home/ptorras/DATA/DoloresDB/Alignments")
right_annotation_path = Path("/home/ptorras/DATA/DoloresDB/CorrectedAlignments")

for alignment_file in wrong_annotation_path.glob("*.json"):
    with open(alignment_file) as f_in:
        data = json.load(f_in)

    new_data = data.copy()

    if alignment_file.name not in line_mappings:
        continue

    translation = line_mappings[alignment_file.name]

    for ann in new_data["annotations"]:
        if ann["id"] in translation:
            ann["id"] = translation[ann["id"]]

    with open(right_annotation_path / alignment_file.name, "w") as f_out:
        json.dump(new_data, f_out, indent=4)

# %%
with open("./wrong_ids_corrected.json") as f_in:
    wrong_ids = json.load(f_in)
len(wrong_ids)
# Out:
# 309

# %%
len(wrong_ids["XAC_ACUR_TagFAu128_029_final.json"]["errors"])
# Out:
# 183

# %%
line_mappings["XAC_ACGAX_SEOAu942.02_004_final.json"]
# Out:
# {'line4:E0A3-1fpfrpq': 'line4:E0A3-ioquh7',
#  'line4:E083-1fpfrpq': 'line4:E083-ioquh7',
#  'line4:E084-1fpfrpq': 'line4:E084-ioquh7',
#  'line4:E0A4-1fpfrpq': 'line4:E0A4-ioquh7',
#  'line4:E261-1fpfrpq': 'line4:E261-ioquh7',
#  'line4:E240-1fpfrpq': 'line4:E240-ioquh7',
#  'line4:E4E6-1fpfrpq': 'line4:E4E6-ioquh7',
#  'line4:E220-1fpfrpq': 'line4:E220-ioquh7',
#  'line4:E4A3-1fpfrpq': 'line4:E4A3-ioquh7',
#  'line4:s17i2tnt': 'line4:s1dnlne5',
#  'line4:l1dhaef6': 'line4:l1wyxf0p',
#  'line4:t1k7hdsy': 'line4:t10hiki3',
#  'line4:s115fo85': 'line4:snfsmir',
#  'line4:m1s31hvy_1': 'line4:time1_1',
#  'line4:lru7x7h': 'line4:l1nc8ggw',
#  'line4:smn6wjv': 'line4:note1.stem',
#  'line4:s1mird70': 'line4:note2.stem',
#  'line4:ss9sibq': 'line4:note3.stem',
#  'line4:aty9ko': 'line4:note3.articulation1.staccato',
#  'line4:s1ilalui': 'line4:note4.stem',
#  'line4:bi4mh1c': 'line4:pP1_m1.right_barline',
#  'line4:bi4mh1c.barline_tok1': 'line4:pP1_m1.right_barline.barline_tok1',
#  'line4:s74r6hb': 'line4:s1okl5go',
#  'line4:lia6veo': 'line4:lf619ee',
#  'line4:s1rsncoh': 'line4:note5.stem',
#  'line4:sahzrw4': 'line4:note6.stem',
#  'line4:suvae92': 'line4:note7.stem',
#  'line4:bpn1vsh': 'line4:pP1_m2.right_barline',
#  'line4:bpn1vsh.barline_tok1': 'line4:pP1_m2.right_barline.barline_tok1',
#  'line4:s6l20xs': 'line4:syut6gc',
#  'line4:l1utmnm8': 'line4:l7cuesf',
#  'line4:sdn90ay': 'line4:note8.stem',
#  'line4:sa9b286': 'line4:note9.stem',
#  'line4:s1yzuq2h': 'line4:note10.stem',
#  'line4:b3tgmzw': 'line4:pP1_m3.right_barline',
#  'line4:b3tgmzw.barline_tok1': 'line4:pP1_m3.right_barline.barline_tok1',
#  'line4:s1jjlqwi': 'line4:s1t6ol4t',
#  'line4:l17h7t13': 'line4:luxpn1u',
#  'line4:skgw3b8': 'line4:note11.stem',
#  'line4:sudk8xa': 'line4:note12.stem',
#  'line4:s18xlzt5': 'line4:note13.stem',
#  'line4:s1x1jdm3': 'line4:note14.stem',
#  'line4:b13mcjg': 'line4:pP1_m4.right_barline',
#  'line4:b13mcjg.barline_tok1': 'line4:pP1_m4.right_barline.barline_tok1',
#  'line4:smk19x6': 'line4:sqcf39u',
#  'line4:l1qkocer': 'line4:l1g2j8bf',
#  'line4:stv8o1w': 'line4:note15.stem',
#  'line4:s13qiyrj': 'line4:note16.stem',
#  'line4:svcwyab': 'line4:note17.stem',
#  'line4:btch3sj': 'line4:pP1_m5.right_barline',
#  'line4:btch3sj.barline_tok1': 'line4:pP1_m5.right_barline.barline_tok1',
#  'line4:s10hsbdr': 'line4:s1x4b09n',
#  'line4:lp8b3bz': 'line4:ltzaf50',
#  'line4:s1tctqjg': 'line4:note18.stem',
#  'line4:s1jbcd83': 'line4:note19.stem',
#  'line4:sevtkcb': 'line4:note20.stem',
#  'line4:b29alp1': 'line4:pP1_m6.right_barline',
#  'line4:b29alp1.barline_tok1': 'line4:pP1_m6.right_barline.barline_tok1',
#  'line4:s1cx5j9x': 'line4:scqjmwu',
#  'line4:l1zkn9': 'line4:lrgq9kl',
#  'line4:s9lrxds': 'line4:note21.stem',
#  'line4:s1qb61bo': 'line4:note22.stem',
#  'line4:s1cu62xt': 'line4:note23.stem',
#  'line4:scn1lny': 'line4:note24.stem',
#  'line4:s1wdekw': 'line4:note25.stem',
#  'line4:auaxdmz': 'line4:note25.accidental',
#  'line4:b18rsgse': 'line4:pP1_m7.right_barline',
#  'line4:b18rsgse.barline_tok1': 'line4:pP1_m7.right_barline.barline_tok1',
#  'line4:spntggq': 'line4:sf5oy42',
#  'line4:l1w89w3b': 'line4:lnsys8o',
#  'line4:s1p0b8z2': 'line4:note26.stem',
#  'line4:su4cs68': 'line4:note27.stem',
#  'line4:s1oj2jt1': 'line4:note28.stem',
#  'line4:si7oh6o': 'line4:note29.stem',
#  'line4:b10yoadx': 'line4:pP1_m8.right_barline',
#  'line4:b10yoadx.barline_tok1': 'line4:pP1_m8.right_barline.barline_tok1',
#  'line4:s1wy8m8v': 'line4:s1x393sg',
#  'line4:l1bkgcvt': 'line4:lht6d7c',
#  'line4:buv230s': 'line4:note30.tremolo_single',
#  'line4:buv230s.line1': 'line4:note30.tremolo_single.line1',
#  'line4:s7a2mc0': 'line4:note30.stem',
#  'line4:b16870nt': 'line4:pP1_m9.right_barline',
#  'line4:b16870nt.barline_tok1': 'line4:pP1_m9.right_barline.barline_tok1',
#  'line4:siwi37t': 'line4:sfjzee',
#  'line4:lkefqhg': 'line4:liyxz1k',
#  'line4:sg0ezb1': 'line4:note31.stem',
#  'line4:sg0ezb1.flag': 'line4:note31.stem.flag',
#  'line4:spcmjdn': 'line4:note32.stem',
#  'line4:spcmjdn.flag': 'line4:note32.stem.flag',
#  'line4:s1y94nal': 'line4:note33.stem',
#  'line4:s1y94nal.flag': 'line4:note33.stem.flag',
#  'line4:b1aibi0v': 'line4:pP1_m10.right_barline',
#  'line4:b1aibi0v.barline_tok1': 'line4:pP1_m10.right_barline.barline_tok1',
#  'line4:sy8kpmg': 'line4:s17gc31n',
#  'line4:lw3ymb5': 'line4:l9gc0mx',
#  'line4:s19uv9jh': 'line4:note34.stem',
#  'line4:s19uv9jh.flag': 'line4:note34.stem.flag',
#  'line4:s1fa3b0r': 'line4:note35.stem',
#  'line4:s1fa3b0r.flag': 'line4:note35.stem.flag',
#  'line4:s1n4ijko': 'line4:note36.stem',
#  'line4:s1n4ijko.flag': 'line4:note36.stem.flag',
#  'line4:bjzqjij': 'line4:pP1_m11.right_barline',
#  'line4:bjzqjij.barline_tok1': 'line4:pP1_m11.right_barline.barline_tok1',
#  'line4:svj7elf': 'line4:s1s9hp6d',
#  'line4:lqy7kfe': 'line4:l1cqe18d',
#  'line4:s5z4cod': 'line4:note37.stem',
#  'line4:s5z4cod.flag': 'line4:note37.stem.flag',
#  'line4:s1sp7rwq': 'line4:note38.stem',
#  'line4:s1sp7rwq.flag': 'line4:note38.stem.flag',
#  'line4:s16ya1lj': 'line4:note39.stem',
#  'line4:s16ya1lj.flag': 'line4:note39.stem.flag',
#  'line4:b1ccgbn3': 'line4:pP1_m12.right_barline',
#  'line4:b1ccgbn3.barline_tok1': 'line4:pP1_m12.right_barline.barline_tok1',
#  'line5:E0A3-3s32sc': 'line5:E0A3-vofpq5',
#  'line5:E083-3s32sc': 'line5:E083-vofpq5',
#  'line5:E084-3s32sc': 'line5:E084-vofpq5',
#  'line5:E0A4-3s32sc': 'line5:E0A4-vofpq5',
#  'line5:E240-3s32sc': 'line5:E240-vofpq5',
#  'line5:E4E6-3s32sc': 'line5:E4E6-vofpq5',
#  'line5:s1xn4o8q': 'line5:smrldq2',
#  'line5:l1ddhohv': 'line5:l17bzshf',
#  'line5:tuxpyix': 'line5:t6ammx5',
#  'line5:sbfupkt': 'line5:symgllz',
#  'line5:muygsox_1': 'line5:time1_1',
#  'line5:l9kfdei': 'line5:l1yrppmh',
#  'line5:s1mmwv38': 'line5:note1.stem',
#  'line5:s1mmwv38.flag': 'line5:note1.stem.flag',
#  'line5:s12s5wac': 'line5:note2.stem',
#  'line5:s12s5wac.flag': 'line5:note2.stem.flag',
#  'line5:sz10msw': 'line5:note3.stem',
#  'line5:sz10msw.flag': 'line5:note3.stem.flag',
#  'line5:b1y27w4c': 'line5:pP1_m1.right_barline',
#  'line5:b1y27w4c.barline_tok1': 'line5:pP1_m1.right_barline.barline_tok1',
#  'line5:s1o4up4': 'line5:slyu92o',
#  'line5:l18au30s': 'line5:l7upd2e',
#  'line5:s1xb9ft': 'line5:note4.stem',
#  'line5:s1xb9ft.flag': 'line5:note4.stem.flag',
#  'line5:si9etk5': 'line5:note5.stem',
#  'line5:si9etk5.flag': 'line5:note5.stem.flag',
#  'line5:s1nm92jp': 'line5:note6.stem',
#  'line5:s1nm92jp.flag': 'line5:note6.stem.flag',
#  'line5:b680u5z': 'line5:pP1_m2.right_barline',
#  'line5:b680u5z.barline_tok1': 'line5:pP1_m2.right_barline.barline_tok1',
#  'line5:s1wrkf7o': 'line5:s1006ueu',
#  'line5:l1jq6f54': 'line5:l1x12oig',
#  'line5:s7l3lx8': 'line5:note7.stem',
#  'line5:s7l3lx8.flag': 'line5:note7.stem.flag',
#  'line5:s1t0woz4': 'line5:note8.stem',
#  'line5:s1t0woz4.flag': 'line5:note8.stem.flag',
#  'line5:sxp3kf0': 'line5:note9.stem',
#  'line5:sxp3kf0.flag': 'line5:note9.stem.flag',
#  'line5:bsswps1': 'line5:pP1_m3.right_barline',
#  'line5:bsswps1.barline_tok1': 'line5:pP1_m3.right_barline.barline_tok1',
#  'line5:s1fwal58': 'line5:s1ndffj4',
#  'line5:ldlfft7': 'line5:lc4l30y',
#  'line5:scds8vo': 'line5:note10.stem',
#  'line5:ss0h8e2': 'line5:note11.stem',
#  'line5:sts7k30': 'line5:note12.stem',
#  'line5:s49xhiq': 'line5:note13.stem',
#  'line5:bsg6ajl': 'line5:pP1_m4.right_barline',
#  'line5:bsg6ajl.barline_tok1': 'line5:pP1_m4.right_barline.barline_tok1',
#  'line5:spea21f': 'line5:s1gxhqby',
#  'line5:l1gn313': 'line5:l1q76wmx',
#  'line5:sj068ai': 'line5:note14.stem',
#  'line5:s1atw5cc': 'line5:note15.stem',
#  'line5:s1xmqznl': 'line5:note16.stem',
#  'line5:b120v8hd': 'line5:pP1_m5.right_barline',
#  'line5:b120v8hd.barline_tok1': 'line5:pP1_m5.right_barline.barline_tok1',
#  'line5:sd0i0fr': 'line5:s1i76uxh',
#  'line5:l1d0151c': 'line5:lj19j59',
#  'line5:sqtc4ll': 'line5:note17.stem',
#  'line5:sk9kj6': 'line5:note18.stem',
#  'line5:s1blshzn': 'line5:note19.stem',
#  'line5:b9i8sme': 'line5:pP1_m6.right_barline',
#  'line5:b9i8sme.barline_tok1': 'line5:pP1_m6.right_barline.barline_tok1',
#  'line5:s3o3fy1': 'line5:sjnupue',
#  'line5:llnm2vf': 'line5:l1wzv2pr',
#  'line5:s94n7k7': 'line5:note20.stem',
#  'line5:s9nho65': 'line5:note21.stem',
#  'line5:svm4zgi': 'line5:note22.stem',
#  'line5:baqoz6p': 'line5:pP1_m7.right_barline',
#  'line5:baqoz6p.barline_tok1': 'line5:pP1_m7.right_barline.barline_tok1',
#  'line5:s1atf5o9': 'line5:sy986zn',
#  'line5:lji4mpo': 'line5:l9vbop7',
#  'line5:sdfqz35': 'line5:note23.stem',
#  'line5:st4wu8x': 'line5:note24.stem',
#  'line5:snwrzxr': 'line5:note25.stem',
#  'line5:bufobas': 'line5:pP1_m8.right_barline',
#  'line5:bufobas.barline_tok1': 'line5:pP1_m8.right_barline.barline_tok1',
#  'line5:sh57fuk': 'line5:sxauk9y',
#  'line5:lm1v5kl': 'line5:l1izb054',
#  'line5:sajel8f': 'line5:note26.stem',
#  'line5:s1lmit4d': 'line5:note27.stem',
#  'line5:b2dtmyu': 'line5:pP1_m9.right_barline',
#  'line5:b2dtmyu.barline_tok1': 'line5:pP1_m9.right_barline.barline_tok1',
#  'line5:s9v0yrd': 'line5:s149k1fq',
#  'line5:l1o38a4m': 'line5:l1a8adf7',
#  'line5:s5lhuqg': 'line5:note28.stem',
#  'line5:s1fr41iw': 'line5:note29.stem',
#  'line5:s1y5azvu': 'line5:note30.stem',
#  'line5:b17zsy9s': 'line5:pP1_m10.right_barline',
#  'line5:b17zsy9s.barline_tok1': 'line5:pP1_m10.right_barline.barline_tok1',
#  'line5:si5mmdu': 'line5:s1lawcqp',
#  'line5:l15qturt': 'line5:lzpk1xr',
#  'line5:skndiyy': 'line5:note31.stem',
#  'line5:s56rlu': 'line5:note32.stem',
#  'line5:b16v3ude': 'line5:pP1_m11.right_barline',
#  'line5:b16v3ude.barline_tok1': 'line5:pP1_m11.right_barline.barline_tok1',
#  'line5:s149n4cj': 'line5:s19kyyty',
#  'line5:lhqrbzi': 'line5:lcn33gq',
#  'line5:s1wvm1gq': 'line5:note33.stem',
#  'line5:s2njidf': 'line5:note34.stem',
#  'line5:s1um450a': 'line5:note35.stem',
#  'line5:b1hqwrn': 'line5:pP1_m12.right_barline',
#  'line5:b1hqwrn.barline_tok1': 'line5:pP1_m12.right_barline.barline_tok1',
#  'line1:E0A3-1y8xnm3': 'line1:E0A3-q846qk',
#  'line1:E0A4-1y8xnm3': 'line1:E0A4-q846qk',
#  'line1:E241-1y8xnm3': 'line1:E241-q846qk',
#  'line1:E08A-1y8xnm3': 'line1:E08A-q846qk',
#  'line1:E4E5-1y8xnm3': 'line1:E4E5-q846qk',
#  'line1:E220-1y8xnm3': 'line1:E220-q846qk',
#  'line1:E4E4-1y8xnm3': 'line1:E4E4-q846qk',
#  'line1:E4E3-1y8xnm3': 'line1:E4E3-q846qk',
#  'line1:s1uc4ch0': 'line1:s1z13esn',
#  'line1:g1u9pfi6': 'line1:gukfimo',
#  'line1:l1m84dlu': 'line1:loyp8lb',
#  'line1:t1yizpr7': 'line1:t13ozjcv',
#  'line1:s16uje05': 'line1:s74wx9f',
#  'line1:m1iy2gj_1': 'line1:time1_1',
#  'line1:l1a2mgp9': 'line1:l13igdne',
#  'line1:sqnfkk3': 'line1:s1dyqp4m',
#  'line1:m14q87a3_1': 'line1:time1_2',
#  'line1:l9jx3s1': 'line1:l1693u91',
#  'line1:sr20y6q': 'line1:note1.stem',
#  'line1:s16vqbof': 'line1:note2.stem',
#  'line1:syco5ay': 'line1:note3.stem',
#  'line1:sgsouet': 'line1:note4.stem',
#  'line1:bj7w7pg': 'line1:pP1_m1.right_barline',
#  'line1:bj7w7pg.barline_tok1': 'line1:pP1_m1.right_barline.barline_tok1',
#  'line1:s1lrtyig': 'line1:s1rlcz16',
#  'line1:l1jdbl6v': 'line1:lxtk4aj',
#  'line1:s1gkx4yi': 'line1:s1kos6xo',
#  'line1:l1riefu1': 'line1:llev19u',
#  'line1:bqamb5r': 'line1:note5.tremolo_single',
#  'line1:bqamb5r.line1': 'line1:note5.tremolo_single.line1',
#  'line1:s1ghbgie': 'line1:note5.stem',
#  'line1:bjh1jhj': 'line1:note6.tremolo_single',
#  'line1:bjh1jhj.line1': 'line1:note6.tremolo_single.line1',
#  'line1:s1ou6dqr': 'line1:note6.stem',
#  'line1:bj3p638': 'line1:pP1_m2.right_barline',
#  'line1:bj3p638.barline_tok1': 'line1:pP1_m2.right_barline.barline_tok1',
#  'line1:s26wb5h': 'line1:s63x52t',
#  'line1:l5u3j0q': 'line1:l5givvs',
#  'line1:s1hmecz1': 'line1:note7.stem',
#  'line1:sz9a7ry': 'line1:s17i2amj',
#  'line1:l1xk9x49': 'line1:l1ys234p',
#  'line1:s1wv0dr7': 'line1:note8.stem',
#  'line1:s1i32egn': 'line1:note9.stem',
#  'line1:szgr8oj': 'line1:note10.stem',
#  'line1:b1x5h407': 'line1:pP1_m3.right_barline',
#  'line1:b1x5h407.barline_tok1': 'line1:pP1_m3.right_barline.barline_tok1',
#  'line1:s13koo8m': 'line1:s1rdv5fr',
#  'line1:llsicnc': 'line1:lnutr8i',
#  'line1:shymdsk': 'line1:note11.stem',
#  'line1:s4fctn3': 'line1:note12.stem',
#  'line1:sbpyish': 'line1:note13.stem',
#  'line1:sywz35': 'line1:note14.stem',
#  'line1:swu9vp5': 'line1:s1si3vrt',
#  'line1:lkgy3ov': 'line1:l7fifut',
#  'line1:sq98h61': 'line1:note15.stem',
#  'line1:s1u7dbcr': 'line1:note16.stem',
#  'line1:sh7bbtz': 'line1:note17.stem',
#  'line1:s175e0x6': 'line1:note18.stem',
#  'line1:b101unjq': 'line1:pP1_m4.right_barline',
#  'line1:b101unjq.barline_tok1': 'line1:pP1_m4.right_barline.barline_tok1',
#  'line1:slg18l3': 'line1:sklu7z',
#  'line1:lpmt1wg': 'line1:lmd1h7z',
#  'line1:szz3906': 'line1:note19.stem',
#  'line1:shf7qxe': 'line1:note20.stem',
#  'line1:shf7qxe.flag': 'line1:note20.stem.flag',
#  'line1:sko5fu6': 'line1:note21.stem',
#  'line1:sde6jsv': 'line1:s3sdaqt',
#  'line1:lr07uc2': 'line1:l14odn2c',
#  'line1:st3e19w': 'line1:note22.stem',
#  'line1:s1mclqvw': 'line1:note23.stem',
#  'line1:s1mclqvw.flag': 'line1:note23.stem.flag',
#  'line1:s1u24jha': 'line1:note24.stem',
#  'line1:shivdyd': 'line1:note25.stem',
#  'line1:sc2rykc': 'line1:note26.stem',
#  'line1:bf3clso': 'line1:pP1_m5.right_barline',
#  'line1:bf3clso.barline_tok1': 'line1:pP1_m5.right_barline.barline_tok1',
#  'line1:s7jim4a': 'line1:s12ajsnm',
#  'line1:l1lj4r28': 'line1:l1pdvc70',
#  'line1:sxdnccm': 'line1:s1fboost',
#  'line1:luu7woi': 'line1:lhe3peo',
#  'line1:s44ib0s': 'line1:note27.stem',
#  'line1:szhkcf7': 'line1:note28.stem',
#  'line1:biup6e1': 'line1:pP1_m6.right_barline',
#  'line1:biup6e1.barline_tok1': 'line1:pP1_m6.right_barline.barline_tok1',
#  'line1:s71vfsw': 'line1:sowtexi',
#  'line1:lw8tqzl': 'line1:l15ne5o4',
#  'line1:s1pf3aih': 'line1:s1cvlir4',
#  'line1:l15mrxej': 'line1:lll6gq1',
#  'line1:sc4hz9w': 'line1:note29.stem',
#  'line1:s1rre03j': 'line1:note30.stem',
#  'line1:b1rsp8j1': 'line1:pP1_m7.right_barline',
#  'line1:b1rsp8j1.barline_tok1': 'line1:pP1_m7.right_barline.barline_tok1',
#  'line1:s125batt': 'line1:s3jyrwi',
#  'line1:l1xwkh9': 'line1:l1cjl87x',
#  'line1:s11t15bf': 'line1:s1fi1cr6',
#  'line1:l1f2nmpz': 'line1:ldtzw2v',
#  'line1:s1dlkeb7': 'line1:note31.stem',
#  'line1:s1oqsqwr': 'line1:note32.stem',
#  'line1:b1hhiov3': 'line1:pP1_m8.right_barline',
#  'line1:b1hhiov3.barline_tok1': 'line1:pP1_m8.right_barline.barline_tok1',
#  'line1:s1dti5kp': 'line1:s1ym4zu3',
#  'line1:li86743': 'line1:l11d4wq8',
#  'line1:s12yys3z': 'line1:segrewv',
#  'line1:l2mrn7s': 'line1:l7e9dq6',
#  'line1:sz4q4z5': 'line1:note33.stem',
#  'line1:sueovyk': 'line1:note34.stem',
#  'line1:b1qqtqmn': 'line1:pP1_m9.right_barline',
#  'line1:b1qqtqmn.barline_tok1': 'line1:pP1_m9.right_barline.barline_tok1',
#  'line1:s19oiu6q': 'line1:s7888zx',
#  'line1:l1fjz48o': 'line1:l2kux6o',
#  'line1:s7k02c2': 'line1:sjlklak',
#  'line1:l1e225xc': 'line1:l1bupj2d',
#  'line1:s231ije': 'line1:note35.stem',
#  'line1:szz2p3': 'line1:note36.stem',
#  'line1:bd002nf': 'line1:pP1_m10.right_barline',
#  'line1:bd002nf.barline_tok1': 'line1:pP1_m10.right_barline.barline_tok1',
#  'line2:E0A3-1bo47dj': 'line2:E0A3-1n7lqw',
#  'line2:E0A4-1bo47dj': 'line2:E0A4-1n7lqw',
#  'line2:E08A-1bo47dj': 'line2:E08A-1n7lqw',
#  'line2:E4E5-1bo47dj': 'line2:E4E5-1n7lqw',
#  'line2:E4E4-1bo47dj': 'line2:E4E4-1n7lqw',
#  'line2:E4E3-1bo47dj': 'line2:E4E3-1n7lqw',
#  'line2:s1v70v1m': 'line2:svdhu83',
#  'line2:gpfi3xi': 'line2:glqqzmk',
#  'line2:l1jthzfn': 'line2:l16tdkri',
#  'line2:t1m4x8ox': 'line2:ts2t86w',
#  'line2:s1q2n8lk': 'line2:st1euuv',
#  'line2:mv0k4ii_1': 'line2:time1_1',
#  'line2:lklciyp': 'line2:lg7k3i',
#  'line2:se318gr': 'line2:sii771z',
#  'line2:m1an0uk1_1': 'line2:time1_2',
#  'line2:l18rc554': 'line2:lk6eddi',
#  'line2:s15nahw3': 'line2:note1.stem',
#  'line2:s1a2acau': 'line2:note2.stem',
#  'line2:b1chzm3v': 'line2:pP1_m1.right_barline',
#  'line2:b1chzm3v.barline_tok1': 'line2:pP1_m1.right_barline.barline_tok1',
#  'line2:sx9vdl4': 'line2:subt6ii',
#  'line2:l1mh42vp': 'line2:l1jirk02',
#  'line2:s472tb7': 'line2:stc2592',
#  'line2:lscvuip': 'line2:l13g6p80',
#  'line2:sseeg4u': 'line2:note3.stem',
#  'line2:s15qbj4h': 'line2:note4.stem',
#  'line2:b1yytwwe': 'line2:pP1_m2.right_barline',
#  'line2:b1yytwwe.barline_tok1': 'line2:pP1_m2.right_barline.barline_tok1',
#  'line2:s1wz5n10': 'line2:shepj7b',
#  'line2:laeqvbz': 'line2:lpubd01',
#  'line2:sb9z7kw': 'line2:s1a98qa9',
#  'line2:l1ao1w4f': 'line2:l5ww0xj',
#  'line2:siecex3': 'line2:note5.stem',
#  'line2:s1qvtivn': 'line2:note6.stem',
#  'line2:s1rkk3qb': 'line2:note7.stem',
#  'line2:s4lazpp': 'line2:note8.stem',
#  'line2:bvr4856': 'line2:pP1_m3.right_barline',
#  'line2:bvr4856.barline_tok1': 'line2:pP1_m3.right_barline.barline_tok1',
#  'line2:s1yf96v3': 'line2:s13asfdr',
#  'line2:l1lf4ngl': 'line2:l1n9dn62',
#  'line2:skuplw8': 'line2:note9.stem',
#  'line2:s1q42xic': 'line2:note10.stem',
#  'line2:s1es9bbc': 'line2:note11.stem',
#  'line2:so7pirn': 'line2:note12.stem',
#  'line2:s1vyll22': 'line2:note13.stem',
#  'line2:s1df2sgj': 'line2:sxt77vm',
#  'line2:l1hgscde': 'line2:l1ret9y4',
#  'line2:s1urbu93': 'line2:note14.stem',
#  'line2:s1ieze0h': 'line2:note15.stem',
#  'line2:s8xktvt': 'line2:note16.stem',
#  'line2:b2zicjg': 'line2:pP1_m4.right_barline',
#  'line2:b2zicjg.barline_tok1': 'line2:pP1_m4.right_barline.barline_tok1',
#  'line2:s1e9v2s': 'line2:s1c7p5p7',
#  'line2:l1ytasgk': 'line2:l1m797z7',
#  'line2:sgz4jq6': 'line2:note17.stem',
#  'line2:s13hyqng': 'line2:note18.stem',
#  'line2:s1oe0cjg': 'line2:note19.stem',
#  'line2:s1f1upm': 'line2:note20.stem',
#  'line2:s1p3m2e3': 'line2:note21.stem',
#  'line2:s1varwqh': 'line2:s1htfyq9',
#  'line2:lvyczni': 'line2:l1bhnx2w',
#  'line2:s1fmhg7a': 'line2:note22.stem',
#  'line2:sm1j0a2': 'line2:note23.stem',
#  'line2:beu284k': 'line2:pP1_m5.right_barline',
#  'line2:beu284k.barline_tok1': 'line2:pP1_m5.right_barline.barline_tok1',
#  'line2:s1q10p4r': 'line2:s4gm90t',
#  'line2:l15tntzf': 'line2:l1ulpfpr',
#  'line2:saybz45': 'line2:note24.stem',
#  'line2:s14l4ohm': 'line2:note25.stem',
#  'line2:s552byl': 'line2:note26.stem',
#  'line2:s1kl3n1q': 'line2:s1kaetl3',
#  'line2:l12as8gd': 'line2:l1702d3r',
#  'line2:s1wr8m67': 'line2:note27.stem',
#  'line2:s10y3opo': 'line2:note28.stem',
#  'line2:b14zgcie': 'line2:pP1_m6.right_barline',
#  'line2:b14zgcie.barline_tok1': 'line2:pP1_m6.right_barline.barline_tok1',
#  'line2:s1x3ee4o': 'line2:s15fz8zw',
#  'line2:l1t29r6i': 'line2:l1oj48xi',
#  'line2:sn42qpy': 'line2:note29.stem',
#  'line2:s1owe274': 'line2:note30.stem',
#  'line2:s113iavp': 'line2:note31.stem',
#  'line2:ss5f88d': 'line2:note32.stem',
#  'line2:s19pcnr7': 'line2:note33.stem',
#  'line2:s199ldfj': 'line2:su948i4',
#  'line2:lwmq8ke': 'line2:lhiheb1',
#  'line2:sxeb6q9': 'line2:note34.stem',
#  'line2:s14qnzlt': 'line2:note35.stem',
#  'line2:s10ic192': 'line2:note36.stem',
#  'line2:s4q9ry6': 'line2:note37.stem',
#  'line2:b55dys5': 'line2:pP1_m7.right_barline',
#  'line2:b55dys5.barline_tok1': 'line2:pP1_m7.right_barline.barline_tok1',
#  'line2:sfq2veo': 'line2:sq1mbld',
#  'line2:lv0wiqy': 'line2:lg9x269',
#  'line2:sf7eu5s': 'line2:note38.stem',
#  'line2:s5eraxg': 'line2:note39.stem',
#  'line2:s1230rqt': 'line2:sfcrgnc',
#  'line2:lg1n4yl': 'line2:lfoic5i',
#  'line2:s1w6axah': 'line2:note40.stem',
#  'line2:s69r4xp': 'line2:note41.stem',
#  'line2:srtnfrg': 'line2:note42.stem',
#  'line2:s10h5xkf': 'line2:note43.stem',
#  'line2:b18mbc7e': 'line2:pP1_m8.right_barline',
#  'line2:b18mbc7e.barline_tok1': 'line2:pP1_m8.right_barline.barline_tok1',
#  'line2:sxegr1t': 'line2:s1hnyen7',
#  'line2:lnur2xb': 'line2:l3p17yi',
#  'line2:s11or0wt': 'line2:note44.stem',
#  'line2:svm0vy0': 'line2:note45.stem',
#  'line2:s8wj8j2': 'line2:s1jqnbm0',
#  'line2:l1s5daeq': 'line2:l3y3iz4',
#  'line2:slzym0t': 'line2:note46.stem',
#  'line2:s14djeh4': 'line2:note47.stem',
#  'line2:sq2uddy': 'line2:note48.stem',
#  'line2:s11var7a': 'line2:note49.stem',
#  'line2:b53dzzn': 'line2:pP1_m9.right_barline',
#  'line2:b53dzzn.barline_tok1': 'line2:pP1_m9.right_barline.barline_tok1',
#  'line2:s12fxivn': 'line2:s1rlh72q',
#  'line2:lu98uwi': 'line2:l16lv1i8',
#  'line2:st6x3y7': 'line2:note50.stem',
#  'line2:s1erexy': 'line2:note51.stem',
#  'line2:s13wq1ap': 'line2:note52.stem',
#  'line2:s1fldhxh': 'line2:note53.stem',
#  'line2:spxviyq': 'line2:soh6et8',
#  'line2:ldeh549': 'line2:l3f1j0k',
#  'line2:sy1fcsl': 'line2:note54.stem',
#  'line2:s3t20vl': 'line2:note55.stem',
#  'line2:s1s63r1n': 'line2:note56.stem',
#  'line2:s15vax00': 'line2:note57.stem',
#  'line2:bh2dy6p': 'line2:pP1_m10.right_barline',
#  'line2:bh2dy6p.barline_tok1': 'line2:pP1_m10.right_barline.barline_tok1',
#  'line3:E0A3-1ka1v1d': 'line3:E0A3-k3w13y',
#  'line3:E083-1ka1v1d': 'line3:E083-k3w13y',
#  'line3:E084-1ka1v1d': 'line3:E084-k3w13y',
#  'line3:E0A4-1ka1v1d': 'line3:E0A4-k3w13y',
#  'line3:E260-1ka1v1d': 'line3:E260-k3w13y',
#  'line3:E4C0-1ka1v1d': 'line3:E4C0-k3w13y',
#  'line3:E4C1-1ka1v1d': 'line3:E4C1-k3w13y',
#  'line3:E241-1ka1v1d': 'line3:E241-k3w13y',
#  'line3:E08A-1ka1v1d': 'line3:E08A-k3w13y',
#  'line3:E4E5-1ka1v1d': 'line3:E4E5-k3w13y',
#  'line3:E243-1ka1v1d': 'line3:E243-k3w13y',
#  'line3:E4E4-1ka1v1d': 'line3:E4E4-k3w13y',
#  'line3:E4E3-1ka1v1d': 'line3:E4E3-k3w13y',
#  'line3:E07C-1ka1v1d': 'line3:E07C-k3w13y',
#  'line3:s1czeo77': 'line3:sy2p9n7',
#  'line3:g1ciww9v': 'line3:g1dwq4bk',
#  'line3:l2osdwv': 'line3:lk49tpr',
#  'line3:t1lbcc5q': 'line3:t1527iop',
#  'line3:s9b778v': 'line3:s1vh6lx3',
#  'line3:m1eft21i_1': 'line3:time1_1',
#  'line3:l1g1qrdt': 'line3:l77rba2',
#  'line3:sdfvzqa': 'line3:note1.stem',
#  'line3:sthki4q': 'line3:note2.stem',
#  'line3:s1qzqeo5': 'line3:note3.stem',
#  'line3:s1qzqeo5.flag': 'line3:note3.stem.flag',
#  'line3:s1se6v3f': 'line3:note4.stem',
#  'line3:s1se6v3f.flag': 'line3:note4.stem.flag',
#  'line3:s1qckecm': 'line3:smbwp2f',
#  'line3:m1upuolg_1': 'line3:time1_2',
#  'line3:l1uwknl0': 'line3:lcrokvs',
#  'line3:s15j49bk': 'line3:note5.stem',
#  'line3:sjwign1': 'line3:note6.stem',
#  'line3:s1bg9ah1': 'line3:note7.stem',
#  'line3:se094vu': 'line3:note8.stem',
#  'line3:b1y0ynaf': 'line3:pP1_m1.right_barline',
#  'line3:b1y0ynaf.barline_tok1': 'line3:pP1_m1.right_barline.barline_tok1',
#  'line3:saxjq6n': 'line3:suviyzu',
#  'line3:l3vvytb': 'line3:l1df1hrl',
#  'line3:s1nyfyug': 'line3:note9.stem',
#  'line3:s1nyfyug.flag': 'line3:note9.stem.flag',
#  'line3:s1ha98du': 'line3:note10.stem',
#  'line3:s1ha98du.flag': 'line3:note10.stem.flag',
#  'line3:s11lslh1': 'line3:note11.stem',
#  'line3:s11lslh1.flag': 'line3:note11.stem.flag',
#  'line3:sym6tg5': 'line3:note12.stem',
#  'line3:sym6tg5.flag': 'line3:note12.stem.flag',
#  'line3:s1snmbcr': 'line3:note13.stem',
#  'line3:spyptwy': 'line3:s1ynxwcy',
#  'line3:ljhukn7': 'line3:ld78yww',
#  'line3:sswv6kr': 'line3:note14.stem',
#  'line3:s15r3joa': 'line3:note15.stem',
#  'line3:s1q2bb9j': 'line3:note16.stem',
#  'line3:s4hwc36': 'line3:note17.stem',
#  'line3:bkgfqab': 'line3:pP1_m2.right_barline',
#  'line3:bkgfqab.barline_tok1': 'line3:pP1_m2.right_barline.barline_tok1',
#  'line3:szkl9jn': 'line3:sfokxqj',
#  'line3:l6gy3tw': 'line3:l72p752',
#  'line3:s192flg2': 'line3:note18.stem',
#  'line3:s1geunjh': 'line3:s1eo2xz0',
#  'line3:l1r1yh1p': 'line3:l11vbr6u',
#  'line3:s13ui0qc': 'line3:note19.stem',
#  'line3:sd0j8em': 'line3:note20.stem',
#  'line3:s1yrebvy': 'line3:note21.stem',
#  'line3:b1suqh25': 'line3:pP1_m3.right_barline',
#  'line3:b1suqh25.barline_tok1': 'line3:pP1_m3.right_barline.barline_tok1',
#  'line3:s13vs3xi': 'line3:s12pggh0',
#  'line3:ltes72z': 'line3:l1prpcl4',
#  'line3:s1km7jjg': 'line3:note22.stem',
#  'line3:skzqf5b': 'line3:note23.stem',
#  'line3:sivrvj5': 'line3:s8akul3',
#  'line3:l4158a3': 'line3:lu09w5',
#  'line3:syh7xy3': 'line3:note24.stem',
#  'line3:s76vaqz': 'line3:note25.stem',
#  'line3:ss1kuzh': 'line3:note26.stem',
#  'line3:bxpb7pa': 'line3:pP1_m4.right_barline',
#  'line3:bxpb7pa.barline_tok1': 'line3:pP1_m4.right_barline.barline_tok1',
#  'line3:sn3yykc': 'line3:sv802w4',
#  'line3:l1f838ul': 'line3:l178qtdw',
#  'line3:s1qpeg3h': 'line3:note27.stem',
#  'line3:s1lu7c8k': 'line3:note28.stem',
#  'line3:swrf0gh': 'line3:note29.stem',
#  'line3:srbk5gd': 'line3:note30.stem',
#  'line3:s1v0d4de': 'line3:s1c36tju',
#  'line3:l1p7l2m4': 'line3:lvs98oc',
#  'line3:s1tcle2j': 'line3:note31.stem',
#  'line3:s5lwx70': 'line3:note32.stem',
#  'line3:s10j3h0q': 'line3:note33.stem',
#  'line3:soqvouc': 'line3:note34.stem',
#  'line3:se2cl2e': 'line3:note35.stem',
#  'line3:b1ikqy0c': 'line3:pP1_m5.right_barline',
#  'line3:b1ikqy0c.barline_tok1': 'line3:pP1_m5.right_barline.barline_tok1',
#  'line3:sg46tt0': 'line3:s1qwtjns',
#  'line3:l2u2ld3': 'line3:l1dwshfn',
#  'line3:syr05gu': 'line3:note36.stem',
#  'line3:s1gscq5a': 'line3:note37.stem',
#  'line3:s15jeepf': 'line3:note38.stem',
#  'line3:s4df9cm': 'line3:note39.stem',
#  'line3:s5m1lud': 'line3:s6d5scy',
#  'line3:l736z6m': 'line3:l18di5yg',
#  'line3:s4v9jp4': 'line3:note40.stem',
#  'line3:s7gcpng': 'line3:note41.stem',
#  'line3:s15ljidp': 'line3:note42.stem',
#  'line3:sxpotmn': 'line3:note43.stem',
#  'line3:b5tu8rz': 'line3:pP1_m6.right_barline',
#  'line3:b5tu8rz.barline_tok1': 'line3:pP1_m6.right_barline.barline_tok1',
#  'line3:s1cu4ige': 'line3:s1osz46n',
#  'line3:l117pu25': 'line3:lx0xgw2',
#  'line3:sr7qssx': 'line3:note44.stem',
#  'line3:s107pm00': 'line3:s1u3f9yi',
#  'line3:ldue4s9': 'line3:l14s6ueh',
#  'line3:s1tv8vu0': 'line3:note45.stem',
#  'line3:s6ee0mr': 'line3:note46.stem',
#  'line3:b1f63jl5': 'line3:pP1_m7.right_barline',
#  'line3:b1f63jl5.barline_tok1': 'line3:pP1_m7.right_barline.barline_tok1',
#  'line3:sugr8hn': 'line3:siuyk6v',
#  'line3:l1ezsyw': 'line3:l1ivvelw',
#  'line3:s5rnet8': 'line3:s13bs7c5',
#  'line3:l15ytm27': 'line3:l1gy8hlv',
#  'line3:s10ry6c0': 'line3:note47.stem',
#  'line3:s1z1q3c': 'line3:note48.stem',
#  'line3:s16ep7ho': 'line3:note49.stem',
#  'line3:s1318jb7': 'line3:note50.stem',
#  'line3:b13dyjq7': 'line3:barline1',
#  'line3:b13dyjq7.barline_tok1': 'line3:barline1.barline_tok1',
#  'line3:b13dyjq7.barline_tok2': 'line3:barline1.barline_tok2',
#  'line3:sibpei9': 'line3:s1awb9h9',
#  'line3:lfksz41': 'line3:l1xzyug0',
#  'line3:s1xj3az9': 'line3:s9x6o99',
#  'line3:l1cyqk8z': 'line3:l1yw5mex',
#  'line3:b1uji772': 'line3:barline2',
#  'line3:b1uji772.barline_tok1': 'line3:barline2.barline_tok1',
#  'line3:b1uji772.barline_tok2': 'line3:barline2.barline_tok2',
#  'line3:s15uz6za': 'line3:sasd3wv',
#  'line3:ku6xhe7': 'line3:key2',
#  'line3:krtp2j9': 'line3:key2.accidental1',
#  'line3:kvck5l': 'line3:key2.accidental2',
#  'line3:m16ygy80_1': 'line3:time2_1',
#  'line3:l9rqwh2': 'line3:l1d86ubs',
#  'line3:s117yqtx': 'line3:s15yip3d',
#  'line3:kpognh5': 'line3:key2',
#  'line3:kh5mcqn': 'line3:key2.accidental1',
#  'line3:k17xzp2n': 'line3:key2.accidental2',
#  'line3:m1tp04wb_1': 'line3:time2_2',
#  'line3:lg824sf': 'line3:l1nvvqe4',
#  'line3:s1da8tey': 'line3:note51.stem',
#  'line3:sce77mo': 'line3:note52.stem',
#  'line3:b18wh3iz': 'line3:pP1_m10.right_barline',
#  'line3:b18wh3iz.barline_tok1': 'line3:pP1_m10.right_barline.barline_tok1',
#  'line6:E0A3-oglbro': 'line6:E0A3-1bsm8mp',
#  'line6:E083-oglbro': 'line6:E083-1bsm8mp',
#  'line6:E084-oglbro': 'line6:E084-1bsm8mp',
#  'line6:E0A4-oglbro': 'line6:E0A4-1bsm8mp',
#  'line6:E260-oglbro': 'line6:E260-1bsm8mp',
#  'line6:E4C1-oglbro': 'line6:E4C1-1bsm8mp',
#  'line6:E241-oglbro': 'line6:E241-1bsm8mp',
#  'line6:E4E5-oglbro': 'line6:E4E5-1bsm8mp',
#  'line6:E220-oglbro': 'line6:E220-1bsm8mp',
#  'line6:E4E3-oglbro': 'line6:E4E3-1bsm8mp',
#  'line6:E07C-oglbro': 'line6:E07C-1bsm8mp',
#  'line6:s4uaz5y': 'line6:synrld5',
#  'line6:l2wtxan': 'line6:l1undqak',
#  'line6:t1gljxmw': 'line6:t7qrmqp',
#  'line6:s8tss5p': 'line6:samzgr6',
#  'line6:mnzv5f9_1': 'line6:time1_1',
#  'line6:l1p09ikd': 'line6:lne5szo',
#  'line6:s18h3zez': 'line6:note1.stem',
#  'line6:s1kp9dgd': 'line6:note2.stem',
#  'line6:s3nvei5': 'line6:note3.stem',
#  'line6:s1liz5it': 'line6:note4.stem',
#  'line6:s196037b': 'line6:note5.stem',
#  'line6:sfi9pbt': 'line6:s1shmdfi',
#  'line6:m2six2a_1': 'line6:time1_2',
#  'line6:l1j4ydut': 'line6:lrs4rww',
#  'line6:bdsrxo8': 'line6:pP1_m1.right_barline',
#  'line6:bdsrxo8.barline_tok1': 'line6:pP1_m1.right_barline.barline_tok1',
#  'line6:s1926onl': 'line6:sjxux6w',
#  'line6:l1dxsywj': 'line6:l1gw4kok',
#  'line6:spyoaui': 'line6:note6.stem',
#  'line6:s1mpavoh': 'line6:s6w9qm0',
#  'line6:l1fkhg1x': 'line6:l180iz6o',
#  'line6:b1nc1235': 'line6:barline1',
#  'line6:b1nc1235.barline_tok1': 'line6:barline1.barline_tok1',
#  'line6:b1nc1235.barline_tok2': 'line6:barline1.barline_tok2',
#  'line6:s1x3nr8i': 'line6:swb8mxs',
#  'line6:lto5whg': 'line6:l5dy3fd',
#  'line6:s1r6d748': 'line6:s6drqvi',
#  'line6:l6nqutm': 'line6:l18sx0is',
#  'line6:bx5y9tz': 'line6:barline2',
#  'line6:bx5y9tz.barline_tok1': 'line6:barline2.barline_tok1',
#  'line6:bx5y9tz.barline_tok2': 'line6:barline2.barline_tok2',
#  'line6:sgibz17': 'line6:s1egpjb4',
#  'line6:kvnzbor': 'line6:key2',
#  'line6:k8hne06': 'line6:key2.accidental1',
#  'line6:k13lrqm8': 'line6:key2.accidental2',
#  'line6:kmfp1h2': 'line6:key2.accidental3',
#  'line6:m1apj4mt_1': 'line6:time2_1',
#  'line6:ljznttz': 'line6:l1rrnojn',
#  'line6:si0dnbw': 'line6:s1yxkjjs',
#  'line6:k1wpmae5': 'line6:key2',
#  'line6:kpvxpoi': 'line6:key2.accidental1',
#  'line6:k1s5f9si': 'line6:key2.accidental2',
#  'line6:k1e6kh8o': 'line6:key2.accidental3',
#  'line6:m1gexom7_1': 'line6:time2_2',
#  'line6:l60n1ik': 'line6:lrebz9y',
#  'line6:s1hlz0jb': 'line6:note7.stem',
#  'line6:si7bjo9': 'line6:note8.stem',
#  'line6:sf56kk8': 'line6:note9.stem',
#  'line6:bczzr4e': 'line6:pP1_m4.right_barline',
#  'line6:bczzr4e.barline_tok1': 'line6:pP1_m4.right_barline.barline_tok1',
#  'line6:s1xdioli': 'line6:so8g9yd',
#  'line6:l1volv7f': 'line6:l1usiuwk',
#  'line6:s1g4ek86': 'line6:sftxpnf',
#  'line6:lnzd97e': 'line6:l149oocm',
#  'line6:s1wx8w8k': 'line6:note10.stem',
#  'line6:s15bu7bi': 'line6:note11.stem',
#  'line6:bzp0w17': 'line6:note12.tremolo_single',
#  'line6:bzp0w17.line1': 'line6:note12.tremolo_single.line1',
#  'line6:sdtcja8': 'line6:note12.stem',
#  'line6:bdq37n4': 'line6:pP1_m5.right_barline',
#  'line6:bdq37n4.barline_tok1': 'line6:pP1_m5.right_barline.barline_tok1',
#  'line6:sayd9cd': 'line6:sbhxezw',
#  'line6:l1c2nk41': 'line6:l5ex7m0',
#  'line6:stwt7q4': 'line6:s1fdpgej',
#  'line6:l17z78ob': 'line6:l74hlwf',
#  'line6:soih1zu': 'line6:note13.stem',
#  'line6:s1l5rarb': 'line6:note14.stem',
#  'line6:sxrxfvx': 'line6:note15.stem',
#  'line6:b1o3w222': 'line6:pP1_m6.right_barline',
#  'line6:b1o3w222.barline_tok1': 'line6:pP1_m6.right_barline.barline_tok1',
#  'line6:s5umzc4': 'line6:s7a4e8t',
#  'line6:l1h3h8fu': 'line6:l6kerg5',
#  'line6:s1osied9': 'line6:sprh30d',
#  'line6:lu3k1fd': 'line6:l1dcxbz1',
#  'line6:s1y87piw': 'line6:note16.stem',
#  'line6:schr8jl': 'line6:note17.stem',
#  'line6:bspasf0': 'line6:note18.tremolo_single',
#  'line6:bspasf0.line1': 'line6:note18.tremolo_single.line1',
#  'line6:smlhteg': 'line6:note18.stem',
#  'line6:bxmsri5': 'line6:pP1_m7.right_barline',
#  'line6:bxmsri5.barline_tok1': 'line6:pP1_m7.right_barline.barline_tok1',
#  'line6:s14thc23': 'line6:s19g5p5l',
#  'line6:l1eagf7f': 'line6:l3ev4cb',
#  'line6:sqkr3hk': 'line6:note19.stem',
#  'line6:s14ivqb4': 'line6:note20.stem',
#  'line6:s14ivqb4.flag': 'line6:note20.stem.flag',
#  'line6:sr43wve': 'line6:note21.stem',
#  'line6:s6ufbgy': 'line6:sf1e5z5',
#  'line6:l16vrrrv': 'line6:l1lvn3we',
#  'line6:sepl9uk': 'line6:note22.stem',
#  'line6:s1wgaej3': 'line6:note23.stem',
#  'line6:scqvnm5': 'line6:note24.stem',
#  'line6:b1c3fm6w': 'line6:pP1_m8.right_barline',
#  'line6:b1c3fm6w.barline_tok1': 'line6:pP1_m8.right_barline.barline_tok1',
#  'line6:sh9od6z': 'line6:saiatxm',
#  'line6:lrukdnn': 'line6:lk47xkk',
#  'line6:s11k040l': 'line6:note25.stem',
#  'line6:s1d272i1': 'line6:note26.stem',
#  'line6:so19k5r': 'line6:note27.stem',
#  'line6:sz818o5': 'line6:note28.stem',
#  'line6:srnuz4b': 'line6:note29.stem',
#  'line6:scmops4': 'line6:note30.stem',
#  'line6:s16tdlk4': 'line6:scz3ws1',
#  'line6:l1nh8vbp': 'line6:l6twk3',
#  'line6:sa056gj': 'line6:note31.stem',
#  'line6:s1w6zigc': 'line6:note32.stem',
#  'line6:s19k2hmb': 'line6:note33.stem',
#  'line6:schtpz1': 'line6:note34.stem',
#  'line6:s1ccz6bs': 'line6:note35.stem',
#  'line6:sl0ij8z': 'line6:note36.stem',
#  'line6:bkad4zr': 'line6:pP1_m9.right_barline',
#  'line6:bkad4zr.barline_tok1': 'line6:pP1_m9.right_barline.barline_tok1'}
